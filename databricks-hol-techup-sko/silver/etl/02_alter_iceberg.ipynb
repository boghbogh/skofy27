# %%
# %sql
DECLARE OR REPLACE VARIABLE myusername STRING; 

SET VAR myusername = (select concat( 'silver_', replace(replace(current_user(),'@',''),'.','')));
--SET VAR myusername = 'silver';

# %%
# %sql
use catalog skofy27

# %%
# %sql
ALTER TABLE IDENTIFIER(myusername || '.customers_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');

# %%
# %sql
-- customers_clean
ALTER TABLE IDENTIFIER(myusername || '.customers_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');
REORG TABLE IDENTIFIER(myusername || '.customers_clean') APPLY (PURGE);
ALTER TABLE IDENTIFIER(myusername || '.customers_clean') SET TBLPROPERTIES (
    'delta.universalFormat.enabledFormats' = 'iceberg',
    'delta.enableIcebergCompatV2' = 'true',
    'delta.columnMapping.mode' = 'name'
);
REORG TABLE IDENTIFIER(myusername || '.customers_clean') APPLY (UPGRADE UNIFORM(ICEBERG_COMPAT_VERSION=2));

-- inventory_clean
ALTER TABLE IDENTIFIER(myusername || '.inventory_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');
REORG TABLE IDENTIFIER(myusername || '.inventory_clean') APPLY (PURGE);
ALTER TABLE IDENTIFIER(myusername || '.inventory_clean') SET TBLPROPERTIES (
    'delta.universalFormat.enabledFormats' = 'iceberg',
    'delta.enableIcebergCompatV2' = 'true',
    'delta.columnMapping.mode' = 'name'
);
REORG TABLE IDENTIFIER(myusername || '.inventory_clean') APPLY (UPGRADE UNIFORM(ICEBERG_COMPAT_VERSION=2));

-- order_items_clean
ALTER TABLE IDENTIFIER(myusername || '.order_items_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');
REORG TABLE IDENTIFIER(myusername || '.order_items_clean') APPLY (PURGE);
ALTER TABLE IDENTIFIER(myusername || '.order_items_clean') SET TBLPROPERTIES (
    'delta.universalFormat.enabledFormats' = 'iceberg',
    'delta.enableIcebergCompatV2' = 'true',
    'delta.columnMapping.mode' = 'name'
);
REORG TABLE IDENTIFIER(myusername || '.order_items_clean') APPLY (UPGRADE UNIFORM(ICEBERG_COMPAT_VERSION=2));

-- orders_clean
ALTER TABLE IDENTIFIER(myusername || '.orders_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');
REORG TABLE IDENTIFIER(myusername || '.orders_clean') APPLY (PURGE);
ALTER TABLE IDENTIFIER(myusername || '.orders_clean') SET TBLPROPERTIES (
    'delta.universalFormat.enabledFormats' = 'iceberg',
    'delta.enableIcebergCompatV2' = 'true',
    'delta.columnMapping.mode' = 'name'
);
REORG TABLE IDENTIFIER(myusername || '.orders_clean') APPLY (UPGRADE UNIFORM(ICEBERG_COMPAT_VERSION=2));

-- products_clean
ALTER TABLE IDENTIFIER(myusername || '.products_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');
REORG TABLE IDENTIFIER(myusername || '.products_clean') APPLY (PURGE);
ALTER TABLE IDENTIFIER(myusername || '.products_clean') SET TBLPROPERTIES (
    'delta.universalFormat.enabledFormats' = 'iceberg',
    'delta.enableIcebergCompatV2' = 'true',
    'delta.columnMapping.mode' = 'name'
);
REORG TABLE IDENTIFIER(myusername || '.products_clean') APPLY (UPGRADE UNIFORM(ICEBERG_COMPAT_VERSION=2));

-- reviews_clean
ALTER TABLE IDENTIFIER(myusername || '.reviews_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');
REORG TABLE IDENTIFIER(myusername || '.reviews_clean') APPLY (PURGE);
ALTER TABLE IDENTIFIER(myusername || '.reviews_clean') SET TBLPROPERTIES (
    'delta.universalFormat.enabledFormats' = 'iceberg',
    'delta.enableIcebergCompatV2' = 'true',
    'delta.columnMapping.mode' = 'name'
);
REORG TABLE IDENTIFIER(myusername || '.reviews_clean') APPLY (UPGRADE UNIFORM(ICEBERG_COMPAT_VERSION=2));

-- web_events_clean
ALTER TABLE IDENTIFIER(myusername || '.web_events_clean') SET TBLPROPERTIES ('delta.enableDeletionVectors' = 'false');
REORG TABLE IDENTIFIER(myusername || '.web_events_clean') APPLY (PURGE);
ALTER TABLE IDENTIFIER(myusername || '.web_events_clean') SET TBLPROPERTIES (
    'delta.universalFormat.enabledFormats' = 'iceberg',
    'delta.enableIcebergCompatV2' = 'true',
    'delta.columnMapping.mode' = 'name'
);
REORG TABLE IDENTIFIER(myusername || '.web_events_clean') APPLY (UPGRADE UNIFORM(ICEBERG_COMPAT_VERSION=2));
